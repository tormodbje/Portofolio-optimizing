# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

tickers = yf.Tickers('EQNR.OL AKRBP.OL VAR.OL SUBC.OL TGS.OL DOFG.OL DNB.OL STB.OL GJF.OL PROT.OL SB1NO.OL MING.OL KOG.OL TOM.OL VEI.OL AFG.OL AUTO.OL WAWI.OL MOWI.OL SALM.OL LSG.OL AUSS.OL ORK.OL EPR.OL NHY.OL YAR.OL BRG.OL ELK.OL VOW.OL NOD.OL TEL.OL VEND.OL ATEA.OL SCATC.OL')
df_close = pd.DataFrame()
for ticker in tickers.tickers.keys():
    df_close[f'{ticker}'] = tickers.tickers[f'{ticker}'].history(start='2025-01-01', end='2025-12-31')['Close']
px.line(df_close[['AKRBP.OL', 'EQNR.OL']])

# %% [markdown]
# # Likevektet portefølje

# %% [markdown]
# # Minimum-variance portefølje

# %% [markdown]
# # Maximum-sharpe portefølje

# %% [markdown]
# # Risk-parity portefølje
